# %%
from pynif import NIFCollection
import os
import xml.etree.ElementTree as ET


#Preconditions: the files are named equally in each of the following directories
collection_name ="AQUAINT_DBpedia" 
path_raw = "/Users/Rico/Desktop/Bachelorarbeit/Datasets/AQUAINT/AQUAINT_dataset/RawTexts"
path_xml = "/Users/Rico/Desktop/Bachelorarbeit/Datasets/AQUAINT/Annotations_DBpedia/htm_dateien"
output_path = "/Users/Rico/Desktop/Bachelorarbeit/Datasets/AQUAINT/Annotations_DBpedia/NIF_dateien"


#creates collection
#collection = NIFCollection(uri=collection_name)

#the code iterates through each file and converts it into NIF

for filename in os.listdir(path_raw):
    if not filename.endswith(".htm"):
        continue
        
    with open(path_raw+"/"+filename, 'r') as f:
        raw_input = f.read()
        raw_input = raw_input.replace('\n',' ')
        #print(filename)
        #print(raw_input)
        #raw_texts.append(t)
        
        #creates collection
        collection = NIFCollection(uri=collection_name)
        
        context = collection.add_context(
            uri=filename,
            mention=raw_input)
        
#------------------------------------------

        tree = ET.parse(path_xml+"/"+filename)
        root = tree.getroot()

        #saves offsets in a list
        beginIndex_list = []
        for i in range(1,len(root)):
            begin = root[i][1].text
            begin = int(begin)
            beginIndex_list.append(begin)
        #print(beginIndex_list) 

        #calculates endIndex and saves it in a list
        endIndex_list = []
        for j in range(1,len(root)):
            begin = int(root[j][1].text)
            length = int(root[j][2].text)
            endIndex_list.append(begin+length)
        #print(endIndex_list)

        #extracts annotation from file
        anno_list = []
        for i in range(1,len(root)):
            anno = root[i][3].text
            anno_list.append(anno)
        anno_list = [x.replace('\n', '') for x in anno_list]
        anno_list = [x.replace('\t', '') for x in anno_list]
        #print(anno_list)
        
#--------------------------------------

        #add context to text
        for i in range(len(beginIndex_list)):
            context.add_phrase(
                beginIndex=beginIndex_list[i],
                endIndex=endIndex_list[i],
                #taClassRef=['http://dbpedia.org/ontology/SportsManager', 'http://dbpedia.org/ontology/Person', 'http://nerd.eurecom.fr/ontology#Person'],
                #score=0.9869992701528016,
                #annotator='http://freme-project.eu/tools/freme-ner',
                taIdentRef=anno_list[i])
        #print(context)   

#------------------------------

        #generates NIF and safes it in file
        generated_nif = collection.dumps(format='turtle')
        print(generated_nif)
        path = output_path+"/"+filename
        output_file = open(path,"w")
        output_file.write(generated_nif)
        output_file.close()
# Out:
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19980604_0787.htm#offset_129_145> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "corporate ethics" ;
#     nif:beginIndex "129"^^xsd:nonNegativeInteger ;
#     nif:endIndex "145"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Business_ethics> .
#
# <APW19980604_0787.htm#offset_14_24> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Viravaidya" ;
#     nif:beginIndex "14"^^xsd:nonNegativeInteger ;
#     nif:endIndex "24"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Mechai_Viravaidya> .
#
# <APW19980604_0787.htm#offset_354_363> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "lifestyle" ;
#     nif:beginIndex "354"^^xsd:nonNegativeInteger ;
#     nif:endIndex "363"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Lifestyle> .
#
# <APW19980604_0787.htm#offset_377_387> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "executives" ;
#     nif:beginIndex "377"^^xsd:nonNegativeInteger ;
#     nif:endIndex "387"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Chief_executive_officer> .
#
# <APW19980604_0787.htm#offset_405_410> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "banks" ;
#     nif:beginIndex "405"^^xsd:nonNegativeInteger ;
#     nif:endIndex "410"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Bank> .
#
# <APW19980604_0787.htm#offset_418_425> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "finance" ;
#     nif:beginIndex "418"^^xsd:nonNegativeInteger ;
#     nif:endIndex "425"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Finance> .
#
# <APW19980604_0787.htm#offset_543_559> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Bank of Thailand" ;
#     nif:beginIndex "543"^^xsd:nonNegativeInteger ;
#     nif:endIndex "559"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Bank_of_Thailand> .
#
# <APW19980604_0787.htm#offset_610_624> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "justice system" ;
#     nif:beginIndex "610"^^xsd:nonNegativeInteger ;
#     nif:endIndex "624"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Legal_systems_of_the_world> .
#
# <APW19980604_0787.htm#offset_75_78> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "SET" ;
#     nif:beginIndex "75"^^xsd:nonNegativeInteger ;
#     nif:endIndex "78"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/SET_Index> .
#
# <APW19980604_0787.htm#offset_766_777> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Thai people" ;
#     nif:beginIndex "766"^^xsd:nonNegativeInteger ;
#     nif:endIndex "777"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Thai_people> .
#
# <APW19980604_0787.htm#offset_844_854> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "newspapers" ;
#     nif:beginIndex "844"^^xsd:nonNegativeInteger ;
#     nif:endIndex "854"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Newspaper> .
#
# <APW19980604_0787.htm#offset_862_873> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "TV stations" ;
#     nif:beginIndex "862"^^xsd:nonNegativeInteger ;
#     nif:endIndex "873"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980604_0787.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Television_channel> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19980604_0787.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19980604_0787.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1375"^^xsd:nonNegativeInteger ;
#     nif:isString "   ENGLISH    Viravaidya  's plan to set up a watchdog company to monitor  SET  -listed companies and expose possible abuses of  corporate ethics  . I agree with him whole-heartedly and would like to know where to mail my checks to subscribe to the company's shares. Could you advise?    Also, I fully support his request for the media to report on the  lifestyle   of former  executives   of the failed  banks   and  finance   companies. We all know too well that these people will not be punished legally because of the inefficiency of the  Bank of Thailand   in collecting evidence against them and of our  justice system   in delivering timely justice. It is the media's job to discover how these guys are better off after destroying our country, and it is the  Thai people  's job to socially punish them.    I would like to propose that  newspapers   and  TV stations  play up this issue (the continued luxurious lifestyle of the former executives) to attract more public attention, and I will give them Bt20,000 of my hard-earned salary with my full blessing.    Artit Krichphiphat (An ordinary Thai citizen who wants to see the right things get done) Editor's note: Khun Mechai will organise a seminar on the plan on June 7 at the Telephone Organisation of Thailand at 10 am. The media already has the duty to cover such issues without additional financial reward.   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19980903_1073.htm#offset_1030_1065> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Association of Art Museum Directors" ;
#     nif:beginIndex "1030"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1065"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Association_of_Art_Museum_Directors> .
#
# <APW19980903_1073.htm#offset_104_122> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Secretary of State" ;
#     nif:beginIndex "104"^^xsd:nonNegativeInteger ;
#     nif:endIndex "122"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Secretary_of_State> .
#
# <APW19980903_1073.htm#offset_126_144> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Madeleine Albright" ;
#     nif:beginIndex "126"^^xsd:nonNegativeInteger ;
#     nif:endIndex "144"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Madeleine_Albright> .
#
# <APW19980903_1073.htm#offset_1284_1296> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Adolf Hitler" ;
#     nif:beginIndex "1284"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1296"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Adolf_Hitler> .
#
# <APW19980903_1073.htm#offset_1302_1309> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Germany" ;
#     nif:beginIndex "1302"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1309"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Germany> .
#
# <APW19980903_1073.htm#offset_248_257> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Holocaust" ;
#     nif:beginIndex "248"^^xsd:nonNegativeInteger ;
#     nif:endIndex "257"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/The_Holocaust> .
#
# <APW19980903_1073.htm#offset_276_281> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Nazis" ;
#     nif:beginIndex "276"^^xsd:nonNegativeInteger ;
#     nif:endIndex "281"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Nazism> .
#
# <APW19980903_1073.htm#offset_323_337> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Thomas Klestil" ;
#     nif:beginIndex "323"^^xsd:nonNegativeInteger ;
#     nif:endIndex "337"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Thomas_Klestil> .
#
# <APW19980903_1073.htm#offset_401_407> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Moscow" ;
#     nif:beginIndex "401"^^xsd:nonNegativeInteger ;
#     nif:endIndex "407"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Moscow> .
#
# <APW19980903_1073.htm#offset_607_620> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "United States" ;
#     nif:beginIndex "607"^^xsd:nonNegativeInteger ;
#     nif:endIndex "620"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/United_States> .
#
# <APW19980903_1073.htm#offset_60_70> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "stolen art" ;
#     nif:beginIndex "60"^^xsd:nonNegativeInteger ;
#     nif:endIndex "70"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Looted_art> .
#
# <APW19980903_1073.htm#offset_664_676> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Viktor Klima" ;
#     nif:beginIndex "664"^^xsd:nonNegativeInteger ;
#     nif:endIndex "676"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Viktor_Klima> .
#
# <APW19980903_1073.htm#offset_701_719> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Wolfgang Schuessel" ;
#     nif:beginIndex "701"^^xsd:nonNegativeInteger ;
#     nif:endIndex "719"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Wolfgang_Schüssel> .
#
# <APW19980903_1073.htm#offset_76_83> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Austria" ;
#     nif:beginIndex "76"^^xsd:nonNegativeInteger ;
#     nif:endIndex "83"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Austria> .
#
# <APW19980903_1073.htm#offset_898_919> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "World Jewish Congress" ;
#     nif:beginIndex "898"^^xsd:nonNegativeInteger ;
#     nif:endIndex "919"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980903_1073.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/World_Jewish_Congress> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19980903_1073.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19980903_1073.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1393"^^xsd:nonNegativeInteger ;
#     nif:isString "   Austrian president tells Albright of effort to identify  stolen art      Austria  's president told  Secretary of State    Madeleine Albright   on Thursday that the government was establishing a commission to identify art which was stolen from  Holocaust   victims by the  Nazis  .    Austrian officials said President  Thomas Klestil   told Albright, who paid a one-day visit to Vienna after the  Moscow   summit, that the commission would first determine the origin of all art works owned by the Federal Museum here.    There was no statement on the art issue by U.S. officials. Albright left for the  United States   after meetings with Klestil, Chancellor  Viktor Klima   and Foreign Minister  Wolfgang Schuessel  .    Austria, the United States and 37 other nations have launched a drive to identify billions of dollars worth of art stolen from Holocaust victims throughout Europe.    The  World Jewish Congress   estimates the current value of stolen art at between dlrs 90 billion and dlrs 140 billion.    In June, the  Association of Art Museum Directors   in the United States recommended that American art museums check their own collections to determine if any works were stolen during the war and set up a worldwide database for tracking.    Austria was absorbed into  Adolf Hitler  's  Germany  in 1938 and was restored as an independent nation following World War II.    rr   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19981022_0710.htm#offset_1102_1113> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "electricity" ;
#     nif:beginIndex "1102"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1113"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Electricity> .
#
# <APW19981022_0710.htm#offset_1205_1219> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "infrastructure" ;
#     nif:beginIndex "1205"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1219"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Infrastructure> .
#
# <APW19981022_0710.htm#offset_1256_1270> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "liberalization" ;
#     nif:beginIndex "1256"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1270"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Liberalization> .
#
# <APW19981022_0710.htm#offset_1454_1464> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "tax breaks" ;
#     nif:beginIndex "1454"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1464"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Tax_exemption> .
#
# <APW19981022_0710.htm#offset_159_172> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "nuclear power" ;
#     nif:beginIndex "159"^^xsd:nonNegativeInteger ;
#     nif:endIndex "172"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Nuclear_power> .
#
# <APW19981022_0710.htm#offset_212_232> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "hydroelectric plants" ;
#     nif:beginIndex "212"^^xsd:nonNegativeInteger ;
#     nif:endIndex "232"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Hydroelectricity> .
#
# <APW19981022_0710.htm#offset_244_269> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "environmental campaigners" ;
#     nif:beginIndex "244"^^xsd:nonNegativeInteger ;
#     nif:endIndex "269"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Environmentalism> .
#
# <APW19981022_0710.htm#offset_334_359> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "four nuclear power plants" ;
#     nif:beginIndex "334"^^xsd:nonNegativeInteger ;
#     nif:endIndex "359"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Nuclear_power_in_Switzerland> .
#
# <APW19981022_0710.htm#offset_426_440> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "power industry" ;
#     nif:beginIndex "426"^^xsd:nonNegativeInteger ;
#     nif:endIndex "440"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Electrical_power_industry> .
#
# <APW19981022_0710.htm#offset_4_9> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Swiss" ;
#     nif:beginIndex "4"^^xsd:nonNegativeInteger ;
#     nif:endIndex "9"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Switzerland> .
#
# <APW19981022_0710.htm#offset_526_539> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "nuclear waste" ;
#     nif:beginIndex "526"^^xsd:nonNegativeInteger ;
#     nif:endIndex "539"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Radioactive_waste> .
#
# <APW19981022_0710.htm#offset_605_619> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "power stations" ;
#     nif:beginIndex "605"^^xsd:nonNegativeInteger ;
#     nif:endIndex "619"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Power_station> .
#
# <APW19981022_0710.htm#offset_784_791> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "cabinet" ;
#     nif:beginIndex "784"^^xsd:nonNegativeInteger ;
#     nif:endIndex "791"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Cabinet> .
#
# <APW19981022_0710.htm#offset_907_925> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Moritz Leuenberger" ;
#     nif:beginIndex "907"^^xsd:nonNegativeInteger ;
#     nif:endIndex "925"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981022_0710.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Moritz_Leuenberger> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19981022_0710.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19981022_0710.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1540"^^xsd:nonNegativeInteger ;
#     nif:isString "    Swiss   government eyes shutting down nuclear power plants   The Swiss government Thursday announced that it is planning the country's eventual exit from  nuclear power  , saying it wants to support instead  hydroelectric plants  .    But  environmental campaigners   criticized the lack of a timeframe for closing the country's  four nuclear power plants  .    Government officials will work with representatives of the  power industry  , environmental groups and local governments to discuss a timetable and removal of  nuclear waste  , a government statement said. It is unrealistic to build more  power stations   because of environmental concerns, the government has said.    Should the discussions between concerned parties fail to produce an agreed timetable, the federal  cabinet   will make the decision, said the statement.    \"We have set out on a new course,'' said Federal Energy Minister  Moritz Leuenberger  . \"Details have yet to be decided.''    In a related move, the federal cabinet ordered energy officials to draw up a discussion paper on changing laws governing the domestic  electricity   market.    The government envisages the creation of a national company to own the power  infrastructure  .    A timeframe for carrying out  liberalization   of the electricity market itself remains to be determined, the cabinet said.    The cabinet said it wants to support hydroelectric plants. It ordered a study of the possibility of  tax breaks  for hydroelectric plants and how to encourage upgrades of those plants.   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19980627_0596.htm#offset_1021_1045> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Communist Party of India" ;
#     nif:beginIndex "1021"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1045"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Communist_Party_of_India> .
#
# <APW19980627_0596.htm#offset_1178_1191> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Indira Gandhi" ;
#     nif:beginIndex "1178"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1191"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Indira_Gandhi> .
#
# <APW19980627_0596.htm#offset_120_130> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "journalist" ;
#     nif:beginIndex "120"^^xsd:nonNegativeInteger ;
#     nif:endIndex "130"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Journalist> .
#
# <APW19980627_0596.htm#offset_191_203> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "brain cancer" ;
#     nif:beginIndex "191"^^xsd:nonNegativeInteger ;
#     nif:endIndex "203"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Brain_tumor> .
#
# <APW19980627_0596.htm#offset_261_269> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Politics" ;
#     nif:beginIndex "261"^^xsd:nonNegativeInteger ;
#     nif:endIndex "269"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Politics> .
#
# <APW19980627_0596.htm#offset_323_340> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Indian newspapers" ;
#     nif:beginIndex "323"^^xsd:nonNegativeInteger ;
#     nif:endIndex "340"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/List_of_newspapers_in_India> .
#
# <APW19980627_0596.htm#offset_529_543> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Prasar Bharati" ;
#     nif:beginIndex "529"^^xsd:nonNegativeInteger ;
#     nif:endIndex "543"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Prasar_Bharati> .
#
# <APW19980627_0596.htm#offset_562_573> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "corporation" ;
#     nif:beginIndex "562"^^xsd:nonNegativeInteger ;
#     nif:endIndex "573"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Corporation> .
#
# <APW19980627_0596.htm#offset_788_807> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Calcutta University" ;
#     nif:beginIndex "788"^^xsd:nonNegativeInteger ;
#     nif:endIndex "807"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/University_of_Calcutta> .
#
# <APW19980627_0596.htm#offset_826_860> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Oxford University's Merton College" ;
#     nif:beginIndex "826"^^xsd:nonNegativeInteger ;
#     nif:endIndex "860"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Merton_College,_Oxford> .
#
# <APW19980627_0596.htm#offset_959_969> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "journalism" ;
#     nif:beginIndex "959"^^xsd:nonNegativeInteger ;
#     nif:endIndex "969"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Journalism> .
#
# <APW19980627_0596.htm#offset_98_103> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "India" ;
#     nif:beginIndex "98"^^xsd:nonNegativeInteger ;
#     nif:endIndex "103"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980627_0596.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/India> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19980627_0596.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19980627_0596.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1399"^^xsd:nonNegativeInteger ;
#     nif:isString "   Nikhil Chakravarty, a top Indian political columnist, dead at 74   Nikhil Chakravarty, one of  India  's best known  journalist  s, has died. He was 74.    Chakravarty was suffering from  brain cancer   and died in hospital on Saturday, his family said.     Politics   was his forte and his columns appeared in leading  Indian newspapers   and magazines.    Chakravarty also started a weekly news magazine, \"Mainstream,'' in 1962 and edited it for more than three decades.    Last year, the government appointed him chief of  Prasar Bharati  , an autonomous  corporation   set up to end government control of radio and television.    Chakravarty declined a top government award in 1990, saying no journalist should be identified with the governing establishment.    He graduated from  Calcutta University   and studied at  Oxford University's Merton College   in England.    Chakravarty taught history at Calcutta University in the 1930s before taking to  journalism   as correspondent of a weekly brought out by the  Communist Party of India  .    He later joined the CPI and remained a member until 1978.    He closed the Mainstream weekly for a while when Prime Minister  Indira Gandhi  imposed emergency rule in India 1975-77, jailing political opponents and imposing censorship on newspapers and magazines.    Chakravarty was born November 3, 1913, in India's northeastern state of Assam.   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19981026_0096.htm#offset_114_139> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "African National Congress" ;
#     nif:beginIndex "114"^^xsd:nonNegativeInteger ;
#     nif:endIndex "139"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/African_National_Congress> .
#
# <APW19981026_0096.htm#offset_1244_1257> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "commissioners" ;
#     nif:beginIndex "1244"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1257"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Commissioner> .
#
# <APW19981026_0096.htm#offset_12_24> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "South Africa" ;
#     nif:beginIndex "12"^^xsd:nonNegativeInteger ;
#     nif:endIndex "24"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/South_Africa> .
#
# <APW19981026_0096.htm#offset_1416_1426> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "land mines" ;
#     nif:beginIndex "1416"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1426"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Land_mine> .
#
# <APW19981026_0096.htm#offset_146_158> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "human rights" ;
#     nif:beginIndex "146"^^xsd:nonNegativeInteger ;
#     nif:endIndex "158"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Human_rights> .
#
# <APW19981026_0096.htm#offset_1479_1485> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Angola" ;
#     nif:beginIndex "1479"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1485"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Angola> .
#
# <APW19981026_0096.htm#offset_184_191> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "torture" ;
#     nif:beginIndex "184"^^xsd:nonNegativeInteger ;
#     nif:endIndex "191"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Torture> .
#
# <APW19981026_0096.htm#offset_199_203> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "bomb" ;
#     nif:beginIndex "199"^^xsd:nonNegativeInteger ;
#     nif:endIndex "203"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Bomb> .
#
# <APW19981026_0096.htm#offset_226_237> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "broadcaster" ;
#     nif:beginIndex "226"^^xsd:nonNegativeInteger ;
#     nif:endIndex "237"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Broadcasting> .
#
# <APW19981026_0096.htm#offset_297_307> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "white rule" ;
#     nif:beginIndex "297"^^xsd:nonNegativeInteger ;
#     nif:endIndex "307"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Dominant_minority> .
#
# <APW19981026_0096.htm#offset_422_457> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Truth and Reconciliation Commission" ;
#     nif:beginIndex "422"^^xsd:nonNegativeInteger ;
#     nif:endIndex "457"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Truth_and_Reconciliation_Commission_(South_Africa)> .
#
# <APW19981026_0096.htm#offset_669_701> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "South African Broadcasting Corp." ;
#     nif:beginIndex "669"^^xsd:nonNegativeInteger ;
#     nif:endIndex "701"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/South_African_Broadcasting_Corporation> .
#
# <APW19981026_0096.htm#offset_74_83> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "apartheid" ;
#     nif:beginIndex "74"^^xsd:nonNegativeInteger ;
#     nif:endIndex "83"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981026_0096.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/History_of_South_Africa_in_the_Apartheid_era> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19981026_0096.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19981026_0096.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1512"^^xsd:nonNegativeInteger ;
#     nif:isString "   Report:  South Africa  n truth panel to condemn ANC   A panel probing  apartheid  -era abuses has accused the  African National Congress   of  human rights   violations, including  torture   and  bomb   attacks, the state  broadcaster   said Monday.    The ANC, which led the struggle against  white rule   and now is in power, previously has acknowledged it was told to expect implication in right violations.    The  Truth and Reconciliation Commission   will release its final report on 2 1-2 years of investigation on Thursday. The report was expected to place overwhelming blame for the era's abuses on white governments and their brutal security services.     South African Broadcasting Corp.   radio said it had been leaked a \"preliminary document'' which condemns the ANC as politically and morally responsible for gross human rights violations during and after the fall of apartheid.    An ANC spokesman, Thabo Masebe, said he believed the news report referred to a commission letter sent in advance \"informing us of its intention to implicate the ANC in gross human rights violations.''    Commission officials could not immediately be reached for comment.    The ANC was nervous enough about the report to request a meeting with  commissioners   earlier this month. The panel refused, to avoid appearing embarrassed.    The party says the accusations against it likely would center on the planting of  land mines   on border farms, abuses at its military camps in  Angola  and bombings.    (djw)   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19980603_1617.htm#offset_1064_1070> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "mussel" ;
#     nif:beginIndex "1064"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1070"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Mussel> .
#
# <APW19980603_1617.htm#offset_1099_1104> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Lukut" ;
#     nif:beginIndex "1099"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1104"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Lukut> .
#
# <APW19980603_1617.htm#offset_116_124> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "economic" ;
#     nif:beginIndex "116"^^xsd:nonNegativeInteger ;
#     nif:endIndex "124"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Economy> .
#
# <APW19980603_1617.htm#offset_1172_1186> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Negri Sembilan" ;
#     nif:beginIndex "1172"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1186"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Negeri_Sembilan> .
#
# <APW19980603_1617.htm#offset_1246_1258> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Port Dickson" ;
#     nif:beginIndex "1246"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1258"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Port_Dickson> .
#
# <APW19980603_1617.htm#offset_1383_1390> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "studies" ;
#     nif:beginIndex "1383"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1390"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Research> .
#
# <APW19980603_1617.htm#offset_228_242> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "implementation" ;
#     nif:beginIndex "228"^^xsd:nonNegativeInteger ;
#     nif:endIndex "242"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Implementation> .
#
# <APW19980603_1617.htm#offset_250_255> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Rural" ;
#     nif:beginIndex "250"^^xsd:nonNegativeInteger ;
#     nif:endIndex "255"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Rural> .
#
# <APW19980603_1617.htm#offset_409_419> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "allocation" ;
#     nif:beginIndex "409"^^xsd:nonNegativeInteger ;
#     nif:endIndex "419"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Resource_allocation> .
#
# <APW19980603_1617.htm#offset_40_47> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Federal" ;
#     nif:beginIndex "40"^^xsd:nonNegativeInteger ;
#     nif:endIndex "47"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Federal_Government> .
#
# <APW19980603_1617.htm#offset_439_447> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "ministry" ;
#     nif:beginIndex "439"^^xsd:nonNegativeInteger ;
#     nif:endIndex "447"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Ministry_(government_department)> .
#
# <APW19980603_1617.htm#offset_472_476> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "poor" ;
#     nif:beginIndex "472"^^xsd:nonNegativeInteger ;
#     nif:endIndex "476"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Poverty> .
#
# <APW19980603_1617.htm#offset_4_12> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "MALAYSIA" ;
#     nif:beginIndex "4"^^xsd:nonNegativeInteger ;
#     nif:endIndex "12"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Malaysia> .
#
# <APW19980603_1617.htm#offset_55_60> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "State" ;
#     nif:beginIndex "55"^^xsd:nonNegativeInteger ;
#     nif:endIndex "60"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/State> .
#
# <APW19980603_1617.htm#offset_64_83> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Government agencies" ;
#     nif:beginIndex "64"^^xsd:nonNegativeInteger ;
#     nif:endIndex "83"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Government_agency> .
#
# <APW19980603_1617.htm#offset_819_827> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "minister" ;
#     nif:beginIndex "819"^^xsd:nonNegativeInteger ;
#     nif:endIndex "827"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980603_1617.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Minister_(government)> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19980603_1617.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19980603_1617.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1446"^^xsd:nonNegativeInteger ;
#     nif:isString "    MALAYSIA     PORT DICKSON, Tues. -  Federal   and  State    Government agencies  , given the task to undertake  economic   projects under the Development Programme for the Hardcore Poor (PPRT), must ensure their successful  implementation  .     Rural   Development Minister Datuk Annuar Musa said yesterday those responsible should closely monitor the implementation of the projects and ensure that the  allocation   provided by the  ministry   benefit the hardcore  poor   participants.    He said those responsible, including district officers, must personally check on the progress of the projects being carried out.    \"We don't want to see projects as being a success on paper but on inspection, they don't show the desired results,'' he added.    According to him, it was the ministry's policy now that the  minister  , deputy minister, parliamentary secretary, director-general and other senior ministry officials had to visit the PPRT projects to see what was happening to the allocation given by the Government.    Annuar said this after visiting a  mussel   rearing project in Kuala  Lukut   today as part of his day-long visit to several PPRT projects in  Negri Sembilan  .    Present were Chembong Assemblyman Firdaus Harun and  Port Dickson   district officer Hassan Nawawi Abdul Rahman.    Annuar added that the implementing agencies should also conduct in-depth  studies  of the projects proposed to ensure their viability.   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19980610_0111.htm#offset_1123_1140> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Leninsk-Kuznetsky" ;
#     nif:beginIndex "1123"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1140"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Leninsk-Kuznetsky_(city)> .
#
# <APW19980610_0111.htm#offset_1193_1198> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "mayor" ;
#     nif:beginIndex "1193"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1198"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Mayor> .
#
# <APW19980610_0111.htm#offset_1218_1227> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "tax fraud" ;
#     nif:beginIndex "1218"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1227"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Tax_avoidance_and_tax_evasion> .
#
# <APW19980610_0111.htm#offset_1235_1247> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "embezzlement" ;
#     nif:beginIndex "1235"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1247"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Embezzlement> .
#
# <APW19980610_0111.htm#offset_1266_1283> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Gennady Konyakhin" ;
#     nif:beginIndex "1266"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1283"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Gennady_Konyakhin> .
#
# <APW19980610_0111.htm#offset_1324_1327> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "mob" ;
#     nif:beginIndex "1324"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1327"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Russian_Mafia> .
#
# <APW19980610_0111.htm#offset_1355_1360> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "trial" ;
#     nif:beginIndex "1355"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1360"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Trial_(law)> .
#
# <APW19980610_0111.htm#offset_159_174> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "organized crime" ;
#     nif:beginIndex "159"^^xsd:nonNegativeInteger ;
#     nif:endIndex "174"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Organized_crime> .
#
# <APW19980610_0111.htm#offset_241_248> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Sibneft" ;
#     nif:beginIndex "241"^^xsd:nonNegativeInteger ;
#     nif:endIndex "248"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Gazprom_Neft> .
#
# <APW19980610_0111.htm#offset_364_372> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Kemerovo" ;
#     nif:beginIndex "364"^^xsd:nonNegativeInteger ;
#     nif:endIndex "372"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Kemerovo> .
#
# <APW19980610_0111.htm#offset_394_401> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Siberia" ;
#     nif:beginIndex "394"^^xsd:nonNegativeInteger ;
#     nif:endIndex "401"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Siberia> .
#
# <APW19980610_0111.htm#offset_44_51> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Russian" ;
#     nif:beginIndex "44"^^xsd:nonNegativeInteger ;
#     nif:endIndex "51"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Russians> .
#
# <APW19980610_0111.htm#offset_506_512> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Russia" ;
#     nif:beginIndex "506"^^xsd:nonNegativeInteger ;
#     nif:endIndex "512"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Russia> .
#
# <APW19980610_0111.htm#offset_587_592> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "mogul" ;
#     nif:beginIndex "587"^^xsd:nonNegativeInteger ;
#     nif:endIndex "592"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Business_magnate> .
#
# <APW19980610_0111.htm#offset_596_612> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Boris Berezovsky" ;
#     nif:beginIndex "596"^^xsd:nonNegativeInteger ;
#     nif:endIndex "612"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Boris_Berezovsky> .
#
# <APW19980610_0111.htm#offset_721_733> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "oil products" ;
#     nif:beginIndex "721"^^xsd:nonNegativeInteger ;
#     nif:endIndex "733"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Oil> .
#
# <APW19980610_0111.htm#offset_741_745> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "coal" ;
#     nif:beginIndex "741"^^xsd:nonNegativeInteger ;
#     nif:endIndex "745"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Coal> .
#
# <APW19980610_0111.htm#offset_783_794> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "coal-mining" ;
#     nif:beginIndex "783"^^xsd:nonNegativeInteger ;
#     nif:endIndex "794"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Coal_mining> .
#
# <APW19980610_0111.htm#offset_948_963> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "contract murder" ;
#     nif:beginIndex "948"^^xsd:nonNegativeInteger ;
#     nif:endIndex "963"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19980610_0111.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Contract_killing> .
#
# <APW19980610_0111.htm#offset_992_1000> a nif:OffsetBasedString,
# ...
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19981119_0585.htm#offset_1177_1184> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "rangers" ;
#     nif:beginIndex "1177"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1184"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Park_ranger> .
#
# <APW19981119_0585.htm#offset_1218_1235> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Apuseni Mountains" ;
#     nif:beginIndex "1218"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1235"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Apuseni_Mountains> .
#
# <APW19981119_0585.htm#offset_145_152> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Romania" ;
#     nif:beginIndex "145"^^xsd:nonNegativeInteger ;
#     nif:endIndex "152"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Romania> .
#
# <APW19981119_0585.htm#offset_192_197> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "sheep" ;
#     nif:beginIndex "192"^^xsd:nonNegativeInteger ;
#     nif:endIndex "197"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Domestic_sheep> .
#
# <APW19981119_0585.htm#offset_247_256> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "livestock" ;
#     nif:beginIndex "247"^^xsd:nonNegativeInteger ;
#     nif:endIndex "256"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Livestock> .
#
# <APW19981119_0585.htm#offset_26_32> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "cattle" ;
#     nif:beginIndex "26"^^xsd:nonNegativeInteger ;
#     nif:endIndex "32"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Cattle> .
#
# <APW19981119_0585.htm#offset_408_416> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "reserves" ;
#     nif:beginIndex "408"^^xsd:nonNegativeInteger ;
#     nif:endIndex "416"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Game_reserve> .
#
# <APW19981119_0585.htm#offset_443_450> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Dracula" ;
#     nif:beginIndex "443"^^xsd:nonNegativeInteger ;
#     nif:endIndex "450"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Dracula> .
#
# <APW19981119_0585.htm#offset_474_486> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Transylvania" ;
#     nif:beginIndex "474"^^xsd:nonNegativeInteger ;
#     nif:endIndex "486"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Transylvania> .
#
# <APW19981119_0585.htm#offset_491_498> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "vampire" ;
#     nif:beginIndex "491"^^xsd:nonNegativeInteger ;
#     nif:endIndex "498"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Vampire> .
#
# <APW19981119_0585.htm#offset_598_607> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "kilograms" ;
#     nif:beginIndex "598"^^xsd:nonNegativeInteger ;
#     nif:endIndex "607"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Kilogram> .
#
# <APW19981119_0585.htm#offset_61_65> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "bear" ;
#     nif:beginIndex "61"^^xsd:nonNegativeInteger ;
#     nif:endIndex "65"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Bear> .
#
# <APW19981119_0585.htm#offset_753_762> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "hibernate" ;
#     nif:beginIndex "753"^^xsd:nonNegativeInteger ;
#     nif:endIndex "762"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Hibernation> .
#
# <APW19981119_0585.htm#offset_75_83> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "peasants" ;
#     nif:beginIndex "75"^^xsd:nonNegativeInteger ;
#     nif:endIndex "83"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Peasant> .
#
# <APW19981119_0585.htm#offset_866_876> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "omnivorous" ;
#     nif:beginIndex "866"^^xsd:nonNegativeInteger ;
#     nif:endIndex "876"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Omnivore> .
#
# <APW19981119_0585.htm#offset_913_919> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "weaned" ;
#     nif:beginIndex "913"^^xsd:nonNegativeInteger ;
#     nif:endIndex "919"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Breastfeeding> .
#
# <APW19981119_0585.htm#offset_945_962> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Nicolae Ceausescu" ;
#     nif:beginIndex "945"^^xsd:nonNegativeInteger ;
#     nif:endIndex "962"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Nicolae_Ceauşescu> .
#
# <APW19981119_0585.htm#offset_971_980> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "communist" ;
#     nif:beginIndex "971"^^xsd:nonNegativeInteger ;
#     nif:endIndex "980"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Communism> .
#
# <APW19981119_0585.htm#offset_984_992> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "dictator" ;
#     nif:beginIndex "984"^^xsd:nonNegativeInteger ;
#     nif:endIndex "992"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981119_0585.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Dictator> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19981119_0585.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19981119_0585.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1305"^^xsd:nonNegativeInteger ;
#     nif:isString "   This \"Dracula'' kills  cattle   and deer   A giant black  bear  , whom  peasants   have nicknamed \"Dracula,'' is creating anxiety in western  Romania   because of his taste for cattle and  sheep  , an official said Thursday.    Peasants whose  livestock   has been devoured by the hungry bear have lodged seven complaints in the past six weeks, said Nicolae Onetiu, head of the state hunting and fishing  reserves   in western Romania.     Dracula   was named after the  Transylvania  n  vampire   count of legend because of his bloody appetite, said Onetiu. The male bruin weighs at least 300  kilograms   (660 pounds) and has moved closer to inhabited areas from forested regions with the onset of cold weather, but is apparently not yet ready to  hibernate  .    Dracula has killed at least six cows and seven sheep over the past six weeks.    Most bears are  omnivorous  , but in Romania, many bears were  weaned   on meat, said Onetiu.  Nicolae Ceausescu  , the  communist    dictator   toppled and executed almost a decade ago, was an avid hunter, and hunting reserve cubs were fed meat to make them grow bigger quicker, leaving generations partial to meat.    State  rangers   count 135 bears living in the  Apuseni Mountains  in western Romania, all of them protected by law.    (str/am/gj )   " .
#
#
# @prefix itsrdf: <http://www.w3.org/2005/11/its/rdf#> .
# @prefix nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#> .
# @prefix ns1: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <APW19981106_0920.htm#offset_1053_1059> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Norway" ;
#     nif:beginIndex "1053"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1059"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Norway> .
#
# <APW19981106_0920.htm#offset_1237_1257> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "hydroelectric plants" ;
#     nif:beginIndex "1237"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1257"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Hydroelectricity> .
#
# <APW19981106_0920.htm#offset_124_132> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "hydrogen" ;
#     nif:beginIndex "124"^^xsd:nonNegativeInteger ;
#     nif:endIndex "132"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Hydrogen> .
#
# <APW19981106_0920.htm#offset_1355_1363> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "nitrogen" ;
#     nif:beginIndex "1355"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1363"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Nitrogen> .
#
# <APW19981106_0920.htm#offset_144_155> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "power plant" ;
#     nif:beginIndex "144"^^xsd:nonNegativeInteger ;
#     nif:endIndex "155"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Power_station> .
#
# <APW19981106_0920.htm#offset_1490_1494> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Oslo" ;
#     nif:beginIndex "1490"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1494"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Oslo> .
#
# <APW19981106_0920.htm#offset_185_196> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "electricity" ;
#     nif:beginIndex "185"^^xsd:nonNegativeInteger ;
#     nif:endIndex "196"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Electricity> .
#
# <APW19981106_0920.htm#offset_235_244> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "emissions" ;
#     nif:beginIndex "235"^^xsd:nonNegativeInteger ;
#     nif:endIndex "244"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Air_pollution> .
#
# <APW19981106_0920.htm#offset_267_286> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "state-owned company" ;
#     nif:beginIndex "267"^^xsd:nonNegativeInteger ;
#     nif:endIndex "286"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Government-owned_corporation> .
#
# <APW19981106_0920.htm#offset_303_351> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Norwegian Water Resources and Energy Directorate" ;
#     nif:beginIndex "303"^^xsd:nonNegativeInteger ;
#     nif:endIndex "351"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Norwegian_Water_Resources_and_Energy_Directorate> .
#
# <APW19981106_0920.htm#offset_63_78> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "Norsk Hydro ASA" ;
#     nif:beginIndex "63"^^xsd:nonNegativeInteger ;
#     nif:endIndex "78"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Norsk_Hydro> .
#
# <APW19981106_0920.htm#offset_809_820> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "natural gas" ;
#     nif:beginIndex "809"^^xsd:nonNegativeInteger ;
#     nif:endIndex "820"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Natural_gas> .
#
# <APW19981106_0920.htm#offset_849_858> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "petroleum" ;
#     nif:beginIndex "849"^^xsd:nonNegativeInteger ;
#     nif:endIndex "858"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Petroleum> .
#
# <APW19981106_0920.htm#offset_965_979> a nif:OffsetBasedString,
#         nif:Phrase ;
#     nif:anchorOf "carbon dioxide" ;
#     nif:beginIndex "965"^^xsd:nonNegativeInteger ;
#     nif:endIndex "979"^^xsd:nonNegativeInteger ;
#     nif:referenceContext <APW19981106_0920.htm> ;
#     itsrdf:taIdentRef <http://dbpedia.org/resource/Carbon_dioxide> .
#
# <AQUAINT_DBpedia> a nif:ContextCollection ;
#     nif:hasContext <APW19981106_0920.htm> ;
#     ns1:conformsTo <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core/2.1> .
#
# <APW19981106_0920.htm> a nif:Context,
#         nif:OffsetBasedString ;
#     nif:beginIndex "0"^^xsd:nonNegativeInteger ;
#     nif:endIndex "1499"^^xsd:nonNegativeInteger ;
#     nif:isString "   Norwegian company moves ahead with clean power plant   The  Norsk Hydro ASA   concern announced plans Friday to build a  hydrogen  -burning  power plant   that it says will produce  electricity   with virtually no climate-damaging  emissions  .    The 51-percent  state-owned company   notified the  Norwegian Water Resources and Energy Directorate   of plans to build the plant, to be called HydroKraft, pending approval by government agencies.    The company said if it receives the proper approvals in 1999, construction of the plant would be completed during 2002 and production startup would occur in early 2003.    Earlier this year, the company announced a new technology that would allow it to use clean-burning hydrogen to generate electricity. The hydrogen for the plant would be extracted from  natural gas  .    Norsk Hydro, a major  petroleum   producer, now says studies have shown the proposal to be economically viable. It also said the plant's  carbon dioxide   emissions would be 90 percent lower than plants using natural gas.     Norway   is the world's second-largest oil exporter, and also produces vast amounts of natural gas from its offshore fields. Virtually all of the country's electricity now comes from  hydroelectric plants  .    Under the company's plans, natural gas, air and water would be mixed to produce hydrogen,  nitrogen   and carbon dioxide.    Norsk Hydro wants to build the plant at Karmoey, an island about 500 kilometers (300 miles) west of  Oslo .   " .
